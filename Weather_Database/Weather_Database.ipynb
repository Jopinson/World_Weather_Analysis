# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather": city_des,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kirtipur
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | huilong
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | saint helens
# Processing Record 8 of Set 1 | xining
# Processing Record 9 of Set 1 | grindavik
# Processing Record 10 of Set 1 | bubaque
# Processing Record 11 of Set 1 | atherton
# Processing Record 12 of Set 1 | kuusamo
# Processing Record 13 of Set 1 | north bend
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | moindou
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | bowen
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | axim
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | pasighat
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | verkhoyansk
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | gorokhovets
# Processing Record 31 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 1 | oistins
# Processing Record 33 of Set 1 | warrington
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | olafsvik
# Processing Record 36 of Set 1 | solnechnyy
# Processing Record 37 of Set 1 | morant bay
# Processing Record 38 of Set 1 | salalah
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | high rock
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | victoria
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | tarakan
# Processing Record 48 of Set 1 | kenai
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | buckeye
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | katsuura
# Processing Record 3 of Set 2 | juegang
# Processing Record 4 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 2 | chapais
# Processing Record 6 of Set 2 | shaoyang
# Processing Record 7 of Set 2 | hofn
# Processing Record 8 of Set 2 | puerto narino
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | nizwa
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | gawler
# Processing Record 13 of Set 2 | zharkovskiy
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | kailua
# Processing Record 16 of Set 2 | flinders
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | muros
# Processing Record 19 of Set 2 | mitsamiouli
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | yarada
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | atambua
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | kavaratti
# Processing Record 29 of Set 2 | talcahuano
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | amazar
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | kavali
# Processing Record 34 of Set 2 | altagracia de orituco
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | mulleriyawa
# Processing Record 38 of Set 2 | nantucket
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | khandyga
# Processing Record 41 of Set 2 | praia da vitoria
# Processing Record 42 of Set 2 | punta arenas
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | matay
# Processing Record 45 of Set 2 | opuwo
# Processing Record 46 of Set 2 | bauska
# Processing Record 47 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | fougamou
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | mbuguni
# Processing Record 5 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 3 | ahipara
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | muana
# Processing Record 11 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 3 | hambantota
# Processing Record 13 of Set 3 | kuching
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | udachnyy
# Processing Record 16 of Set 3 | forrest city
# Processing Record 17 of Set 3 | khvorostyanka
# Processing Record 18 of Set 3 | luderitz
# Processing Record 19 of Set 3 | beira
# Processing Record 20 of Set 3 | peniche
# Processing Record 21 of Set 3 | okato
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | svetlogorsk
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | yerazgavors
# Processing Record 27 of Set 3 | kurilsk
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | port hardy
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 3 | kreuztal
# Processing Record 33 of Set 3 | lompoc
# Processing Record 34 of Set 3 | roros
# Processing Record 35 of Set 3 | nalut
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | thinadhoo
# Processing Record 39 of Set 3 | choya
# Processing Record 40 of Set 3 | bud
# Processing Record 41 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 3 | usinsk
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | lavrentiya
# Processing Record 45 of Set 3 | tuatapere
# Processing Record 46 of Set 3 | ko samui
# Processing Record 47 of Set 3 | tigil
# Processing Record 48 of Set 3 | dorado
# Processing Record 49 of Set 3 | katherine
# Processing Record 50 of Set 3 | aklavik
# Processing Record 1 of Set 4 | kloulklubed
# Processing Record 2 of Set 4 | maceio
# Processing Record 3 of Set 4 | sorland
# Processing Record 4 of Set 4 | albany
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | soe
# Processing Record 7 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 4 | tessalit
# Processing Record 9 of Set 4 | powell
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | hay river
# Processing Record 12 of Set 4 | kyabram
# Processing Record 13 of Set 4 | makakilo city
# Processing Record 14 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 4 | cuenca
# Processing Record 17 of Set 4 | itaqui
# Processing Record 18 of Set 4 | esperance
# Processing Record 19 of Set 4 | tchollire
# Processing Record 20 of Set 4 | high level
# Processing Record 21 of Set 4 | subtanjalla
# Processing Record 22 of Set 4 | porto tolle
# Processing Record 23 of Set 4 | calbuco
# Processing Record 24 of Set 4 | banepa
# Processing Record 25 of Set 4 | yulara
# Processing Record 26 of Set 4 | kismayo
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | leh
# Processing Record 30 of Set 4 | almenara
# Processing Record 31 of Set 4 | illapel
# Processing Record 32 of Set 4 | batagay-alyta
# Processing Record 33 of Set 4 | winnemucca
# Processing Record 34 of Set 4 | airai
# Processing Record 35 of Set 4 | chokwe
# Processing Record 36 of Set 4 | gamboma
# Processing Record 37 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 4 | agadir
# Processing Record 39 of Set 4 | ocho rios
# Processing Record 40 of Set 4 | rocha
# Processing Record 41 of Set 4 | mehamn
# Processing Record 42 of Set 4 | san vicente
# Processing Record 43 of Set 4 | nara
# Processing Record 44 of Set 4 | naze
# Processing Record 45 of Set 4 | douglas
# Processing Record 46 of Set 4 | san cristobal
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | bredasdorp
# Processing Record 49 of Set 4 | baykit
# Processing Record 50 of Set 4 | izhma
# Processing Record 1 of Set 5 | abashiri
# Processing Record 2 of Set 5 | cameron park
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | the valley
# Processing Record 5 of Set 5 | finschhafen
# Processing Record 6 of Set 5 | menongue
# Processing Record 7 of Set 5 | uyemskiy
# Processing Record 8 of Set 5 | norman wells
# Processing Record 9 of Set 5 | monte gordo
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | lannion
# Processing Record 12 of Set 5 | clyde river
# Processing Record 13 of Set 5 | mlowo
# Processing Record 14 of Set 5 | touros
# Processing Record 15 of Set 5 | thompson
# Processing Record 16 of Set 5 | hamilton
# Processing Record 17 of Set 5 | mount isa
# Processing Record 18 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 5 | torbay
# Processing Record 20 of Set 5 | kidal
# Processing Record 21 of Set 5 | manokwari
# Processing Record 22 of Set 5 | nikki
# Processing Record 23 of Set 5 | buala
# Processing Record 24 of Set 5 | kedrovyy
# Processing Record 25 of Set 5 | pacific grove
# Processing Record 26 of Set 5 | mutare
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | concordia
# Processing Record 29 of Set 5 | pucallpa
# Processing Record 30 of Set 5 | helong
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | vung tau
# Processing Record 34 of Set 5 | tautira
# Processing Record 35 of Set 5 | port elizabeth
# Processing Record 36 of Set 5 | katobu
# Processing Record 37 of Set 5 | jasper
# Processing Record 38 of Set 5 | portland
# Processing Record 39 of Set 5 | rorvik
# Processing Record 40 of Set 5 | plettenberg bay
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | golkoy
# Processing Record 43 of Set 5 | khasan
# Processing Record 44 of Set 5 | broome
# Processing Record 45 of Set 5 | saint-leu
# Processing Record 46 of Set 5 | kingaroy
# Processing Record 47 of Set 5 | talnakh
# Processing Record 48 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 5 | angostura
# Processing Record 50 of Set 5 | chiredzi
# Processing Record 1 of Set 6 | sabang
# Processing Record 2 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 6 | sao felix do xingu
# Processing Record 4 of Set 6 | palmer
# Processing Record 5 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 6 | saint george
# Processing Record 7 of Set 6 | villa rica
# Processing Record 8 of Set 6 | ormara
# Processing Record 9 of Set 6 | burica
# City not found. Skipping...
# Processing Record 10 of Set 6 | nemuro
# Processing Record 11 of Set 6 | port-gentil
# Processing Record 12 of Set 6 | te anau
# Processing Record 13 of Set 6 | kapoeta
# Processing Record 14 of Set 6 | carutapera
# Processing Record 15 of Set 6 | young
# Processing Record 16 of Set 6 | biltine
# Processing Record 17 of Set 6 | adrar
# Processing Record 18 of Set 6 | khani
# Processing Record 19 of Set 6 | srednekolymsk
# Processing Record 20 of Set 6 | cap malheureux
# Processing Record 21 of Set 6 | elliot
# Processing Record 22 of Set 6 | tomelloso
# Processing Record 23 of Set 6 | arlit
# Processing Record 24 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 25 of Set 6 | narsaq
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | pekan
# Processing Record 28 of Set 6 | methoni
# Processing Record 29 of Set 6 | severo-kurilsk
# Processing Record 30 of Set 6 | kaabong
# Processing Record 31 of Set 6 | singaparna
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | marystown
# Processing Record 34 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 6 | ballina
# Processing Record 36 of Set 6 | lagoa
# Processing Record 37 of Set 6 | north platte
# Processing Record 38 of Set 6 | bluff
# Processing Record 39 of Set 6 | jibuti
# Processing Record 40 of Set 6 | sisimiut
# Processing Record 41 of Set 6 | horsham
# Processing Record 42 of Set 6 | bandarbeyla
# Processing Record 43 of Set 6 | belyy yar
# Processing Record 44 of Set 6 | moussoro
# Processing Record 45 of Set 6 | lalsk
# Processing Record 46 of Set 6 | araouane
# Processing Record 47 of Set 6 | middle island
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | hakui
# Processing Record 50 of Set 6 | powell river
# Processing Record 1 of Set 7 | woodward
# Processing Record 2 of Set 7 | irtyshskiy
# Processing Record 3 of Set 7 | boa vista
# Processing Record 4 of Set 7 | haines junction
# Processing Record 5 of Set 7 | ouadda
# Processing Record 6 of Set 7 | jesup
# Processing Record 7 of Set 7 | saint-pierre
# Processing Record 8 of Set 7 | bikapur
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | sabha
# Processing Record 11 of Set 7 | jardim
# Processing Record 12 of Set 7 | mahebourg
# Processing Record 13 of Set 7 | byron bay
# Processing Record 14 of Set 7 | sao filipe
# Processing Record 15 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 7 | olga
# Processing Record 17 of Set 7 | cururupu
# Processing Record 18 of Set 7 | upata
# Processing Record 19 of Set 7 | assiniboia
# Processing Record 20 of Set 7 | nipawin
# Processing Record 21 of Set 7 | chunoyar
# Processing Record 22 of Set 7 | inongo
# Processing Record 23 of Set 7 | pangai
# Processing Record 24 of Set 7 | san quintin
# Processing Record 25 of Set 7 | kaspiysk
# Processing Record 26 of Set 7 | houma
# Processing Record 27 of Set 7 | cabo san lucas
# Processing Record 28 of Set 7 | chifeng
# Processing Record 29 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 30 of Set 7 | namibe
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | carballo
# Processing Record 33 of Set 7 | two rivers
# Processing Record 34 of Set 7 | wattegama
# Processing Record 35 of Set 7 | qafsah
# City not found. Skipping...
# Processing Record 36 of Set 7 | tinyahuarco
# Processing Record 37 of Set 7 | kerema
# Processing Record 38 of Set 7 | klaksvik
# Processing Record 39 of Set 7 | ozernovskiy
# Processing Record 40 of Set 7 | gadsden
# Processing Record 41 of Set 7 | kita
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | nabire
# Processing Record 44 of Set 7 | flin flon
# Processing Record 45 of Set 7 | kahului
# Processing Record 46 of Set 7 | san carlos
# Processing Record 47 of Set 7 | faya
# Processing Record 48 of Set 7 | tatawin
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | puerto escondido
# Processing Record 1 of Set 8 | pingdu
# Processing Record 2 of Set 8 | san fernando
# Processing Record 3 of Set 8 | delano
# Processing Record 4 of Set 8 | turukhansk
# Processing Record 5 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 6 of Set 8 | kyshtovka
# Processing Record 7 of Set 8 | tarasovskiy
# Processing Record 8 of Set 8 | sofia
# Processing Record 9 of Set 8 | kormilovka
# Processing Record 10 of Set 8 | ulaanbaatar
# Processing Record 11 of Set 8 | dunedin
# Processing Record 12 of Set 8 | shingu
# Processing Record 13 of Set 8 | andros town
# Processing Record 14 of Set 8 | quatre cocos
# Processing Record 15 of Set 8 | catamarca
# Processing Record 16 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 8 | dharmanagar
# Processing Record 18 of Set 8 | corinto
# Processing Record 19 of Set 8 | sangar
# Processing Record 20 of Set 8 | strezhevoy
# Processing Record 21 of Set 8 | mandalgovi
# Processing Record 22 of Set 8 | kaihua
# Processing Record 23 of Set 8 | saint-joseph
# Processing Record 24 of Set 8 | souillac
# Processing Record 25 of Set 8 | mogadishu
# Processing Record 26 of Set 8 | havre-saint-pierre
# Processing Record 27 of Set 8 | alice springs
# Processing Record 28 of Set 8 | mitu
# Processing Record 29 of Set 8 | nouadhibou
# Processing Record 30 of Set 8 | rawson
# Processing Record 31 of Set 8 | qasigiannguit
# Processing Record 32 of Set 8 | albacete
# Processing Record 33 of Set 8 | alofi
# Processing Record 34 of Set 8 | geraldton
# Processing Record 35 of Set 8 | mokhsogollokh
# Processing Record 36 of Set 8 | ercis
# Processing Record 37 of Set 8 | vestmannaeyjar
# Processing Record 38 of Set 8 | lata
# Processing Record 39 of Set 8 | timmins
# Processing Record 40 of Set 8 | soyo
# Processing Record 41 of Set 8 | kaduqli
# Processing Record 42 of Set 8 | asau
# Processing Record 43 of Set 8 | graaff-reinet
# Processing Record 44 of Set 8 | naberera
# Processing Record 45 of Set 8 | san ramon
# Processing Record 46 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 8 | mombetsu
# Processing Record 48 of Set 8 | timizart
# Processing Record 49 of Set 8 | sao gabriel da cachoeira
# Processing Record 50 of Set 8 | rach gia
# Processing Record 1 of Set 9 | baijiantan
# Processing Record 2 of Set 9 | darnah
# Processing Record 3 of Set 9 | fortuna
# Processing Record 4 of Set 9 | selkirk
# Processing Record 5 of Set 9 | aitape
# Processing Record 6 of Set 9 | gat
# Processing Record 7 of Set 9 | cochrane
# Processing Record 8 of Set 9 | lorengau
# Processing Record 9 of Set 9 | binzhou
# Processing Record 10 of Set 9 | urucara
# Processing Record 11 of Set 9 | sapa
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | solton
# Processing Record 14 of Set 9 | krasnoselkup
# Processing Record 15 of Set 9 | kazerun
# Processing Record 16 of Set 9 | roald
# Processing Record 17 of Set 9 | bilibino
# Processing Record 18 of Set 9 | bambous virieux
# Processing Record 19 of Set 9 | coquimbo
# Processing Record 20 of Set 9 | tual
# Processing Record 21 of Set 9 | umm lajj
# Processing Record 22 of Set 9 | pochutla
# Processing Record 23 of Set 9 | whitehorse
# Processing Record 24 of Set 9 | kruisfontein
# Processing Record 25 of Set 9 | chulman
# Processing Record 26 of Set 9 | drayton valley
# Processing Record 27 of Set 9 | vitim
# Processing Record 28 of Set 9 | kautokeino
# Processing Record 29 of Set 9 | sistranda
# Processing Record 30 of Set 9 | namatanai
# Processing Record 31 of Set 9 | manaure
# Processing Record 32 of Set 9 | saskylakh
# Processing Record 33 of Set 9 | poco verde
# Processing Record 34 of Set 9 | goderich
# Processing Record 35 of Set 9 | launceston
# Processing Record 36 of Set 9 | moses lake
# Processing Record 37 of Set 9 | vardo
# Processing Record 38 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 9 | syamzha
# Processing Record 40 of Set 9 | manggar
# Processing Record 41 of Set 9 | sioux lookout
# Processing Record 42 of Set 9 | chimbote
# Processing Record 43 of Set 9 | japura
# Processing Record 44 of Set 9 | uzumlu
# City not found. Skipping...
# Processing Record 45 of Set 9 | abu dhabi
# Processing Record 46 of Set 9 | santa maria da boa vista
# Processing Record 47 of Set 9 | banjar
# Processing Record 48 of Set 9 | neyshabur
# Processing Record 49 of Set 9 | tsumeb
# Processing Record 50 of Set 9 | hammerfest
# Processing Record 1 of Set 10 | waitati
# Processing Record 2 of Set 10 | fergus falls
# Processing Record 3 of Set 10 | zhigansk
# Processing Record 4 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 10 | waipawa
# Processing Record 6 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 10 | biasca
# Processing Record 8 of Set 10 | ust-nera
# Processing Record 9 of Set 10 | khudumelapye
# Processing Record 10 of Set 10 | sao geraldo do araguaia
# Processing Record 11 of Set 10 | aldan
# Processing Record 12 of Set 10 | kanaya
# Processing Record 13 of Set 10 | neira
# Processing Record 14 of Set 10 | songjianghe
# Processing Record 15 of Set 10 | paiho
# City not found. Skipping...
# Processing Record 16 of Set 10 | mujiayingzi
# Processing Record 17 of Set 10 | mana
# Processing Record 18 of Set 10 | marzuq
# Processing Record 19 of Set 10 | taoudenni
# Processing Record 20 of Set 10 | vegachi
# Processing Record 21 of Set 10 | ledziny
# Processing Record 22 of Set 10 | alta floresta
# Processing Record 23 of Set 10 | saint-francois
# Processing Record 24 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 10 | san joaquin
# Processing Record 26 of Set 10 | isangel
# Processing Record 27 of Set 10 | vila
# Processing Record 28 of Set 10 | kalevala
# Processing Record 29 of Set 10 | kyaukse
# Processing Record 30 of Set 10 | antofagasta
# Processing Record 31 of Set 10 | ilo
# Processing Record 32 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 10 | penarroya-pueblonuevo
# Processing Record 34 of Set 10 | tamandare
# Processing Record 35 of Set 10 | roebourne
# Processing Record 36 of Set 10 | junction city
# Processing Record 37 of Set 10 | los llanos de aridane
# Processing Record 38 of Set 10 | qarqin
# Processing Record 39 of Set 10 | muli
# Processing Record 40 of Set 10 | kathu
# Processing Record 41 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 42 of Set 10 | puerto ayacucho
# Processing Record 43 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 10 | yerbogachen
# Processing Record 45 of Set 10 | rize
# Processing Record 46 of Set 10 | tupik
# Processing Record 47 of Set 10 | deputatskiy
# Processing Record 48 of Set 10 | san mateo ixtatan
# Processing Record 49 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 10 | riyadh
# Processing Record 1 of Set 11 | university park
# Processing Record 2 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 11 | blagoveshchenka
# Processing Record 4 of Set 11 | conde
# Processing Record 5 of Set 11 | broken hill
# Processing Record 6 of Set 11 | qinhuangdao
# Processing Record 7 of Set 11 | richards bay
# Processing Record 8 of Set 11 | christchurch
# Processing Record 9 of Set 11 | nishihara
# Processing Record 10 of Set 11 | vytegra
# Processing Record 11 of Set 11 | bonthe
# Processing Record 12 of Set 11 | dhidhdhoo
# Processing Record 13 of Set 11 | juneau
# Processing Record 14 of Set 11 | anadyr
# Processing Record 15 of Set 11 | gillette
# Processing Record 16 of Set 11 | kieta
# Processing Record 17 of Set 11 | muhlhausen
# Processing Record 18 of Set 11 | ulaangom
# Processing Record 19 of Set 11 | anaco
# Processing Record 20 of Set 11 | zarubino
# Processing Record 21 of Set 11 | beringovskiy
# Processing Record 22 of Set 11 | labuhan
# Processing Record 23 of Set 11 | marsh harbour
# Processing Record 24 of Set 11 | northam
# Processing Record 25 of Set 11 | nhulunbuy
# Processing Record 26 of Set 11 | ust-tsilma
# Processing Record 27 of Set 11 | botwood
# Processing Record 28 of Set 11 | fairbanks
# Processing Record 29 of Set 11 | gigmoto
# Processing Record 30 of Set 11 | makat
# Processing Record 31 of Set 11 | gravelbourg
# Processing Record 32 of Set 11 | zyryanka
# Processing Record 33 of Set 11 | niono
# Processing Record 34 of Set 11 | half moon bay
# Processing Record 35 of Set 11 | pedasi
# Processing Record 36 of Set 11 | brigham city
# Processing Record 37 of Set 11 | murgab
# Processing Record 38 of Set 11 | ituango
# Processing Record 39 of Set 11 | belmopan
# Processing Record 40 of Set 11 | evensk
# Processing Record 41 of Set 11 | nanortalik
# Processing Record 42 of Set 11 | simao
# Processing Record 43 of Set 11 | abapo
# Processing Record 44 of Set 11 | smirnykh
# Processing Record 45 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 11 | marawi
# Processing Record 47 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 48 of Set 11 | at-bashi
# Processing Record 49 of Set 11 | armidale
# Processing Record 50 of Set 11 | olinda
# Processing Record 1 of Set 12 | thunder bay
# Processing Record 2 of Set 12 | progreso
# Processing Record 3 of Set 12 | una
# Processing Record 4 of Set 12 | sabya
# Processing Record 5 of Set 12 | boppard
# Processing Record 6 of Set 12 | mineral wells
# Processing Record 7 of Set 12 | nacozari
# Processing Record 8 of Set 12 | savannah bight
# Processing Record 9 of Set 12 | alpena
# Processing Record 10 of Set 12 | sillod
# Processing Record 11 of Set 12 | gonbad-e qabus
# Processing Record 12 of Set 12 | harrogate
# Processing Record 13 of Set 12 | kayerkan
# Processing Record 14 of Set 12 | port augusta
# Processing Record 15 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 16 of Set 12 | pouso alegre
# Processing Record 17 of Set 12 | sabla
# Processing Record 18 of Set 12 | luganville
# Processing Record 19 of Set 12 | korla
# Processing Record 20 of Set 12 | nam som
# Processing Record 21 of Set 12 | eureka
# Processing Record 22 of Set 12 | ponta delgada
# Processing Record 23 of Set 12 | lagos
# Processing Record 24 of Set 12 | talaya
# Processing Record 25 of Set 12 | piacabucu
# Processing Record 26 of Set 12 | madang
# Processing Record 27 of Set 12 | belturbet
# Processing Record 28 of Set 12 | puerto quijarro
# Processing Record 29 of Set 12 | zapadnaya dvina
# Processing Record 30 of Set 12 | toowoomba
# Processing Record 31 of Set 12 | bukama
# Processing Record 32 of Set 12 | sokoto
# Processing Record 33 of Set 12 | brigantine
# Processing Record 34 of Set 12 | qandala
# Processing Record 35 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing Record 36 of Set 12 | zlobin
# Processing Record 37 of Set 12 | shache
# Processing Record 38 of Set 12 | cockburn town
# Processing Record 39 of Set 12 | guaymas
# Processing Record 40 of Set 12 | anchorage
# Processing Record 41 of Set 12 | wana
# Processing Record 42 of Set 12 | port lincoln
# Processing Record 43 of Set 12 | ostrovnoy
# Processing Record 44 of Set 12 | qui nhon
# Processing Record 45 of Set 12 | bathsheba
# Processing Record 46 of Set 12 | clermont
# Processing Record 47 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 48 of Set 12 | marrakesh
# Processing Record 49 of Set 12 | ancud
# Processing Record 50 of Set 12 | dwarka
# Processing Record 1 of Set 13 | kokopo
# Processing Record 2 of Set 13 | obregon
# Processing Record 3 of Set 13 | mozhaysk
# Processing Record 4 of Set 13 | boda
# Processing Record 5 of Set 13 | harper
# Processing Record 6 of Set 13 | dicabisagan
# Processing Record 7 of Set 13 | cuamba
# Processing Record 8 of Set 13 | pisco
# Processing Record 9 of Set 13 | bucerias
# Processing Record 10 of Set 13 | saharanpur
# Processing Record 11 of Set 13 | dambulla
# Processing Record 12 of Set 13 | guymon
# Processing Record 13 of Set 13 | poronaysk
# Processing Record 14 of Set 13 | inhambane
# Processing Record 15 of Set 13 | chumikan
# Processing Record 16 of Set 13 | altamira
# Processing Record 17 of Set 13 | poum
# Processing Record 18 of Set 13 | danilovka
# Processing Record 19 of Set 13 | grand gaube
# Processing Record 20 of Set 13 | kirakira
# Processing Record 21 of Set 13 | ayan
# Processing Record 22 of Set 13 | laramie
# Processing Record 23 of Set 13 | aswan
# Processing Record 24 of Set 13 | yankton
# Processing Record 25 of Set 13 | port pirie
# Processing Record 26 of Set 13 | merauke
# Processing Record 27 of Set 13 | kamaishi
# Processing Record 28 of Set 13 | nador
# Processing Record 29 of Set 13 | zhicheng
# Processing Record 30 of Set 13 | komsomolskiy
# Processing Record 31 of Set 13 | praia
# Processing Record 32 of Set 13 | kota kinabalu
# Processing Record 33 of Set 13 | westport
# Processing Record 34 of Set 13 | kamenka
# Processing Record 35 of Set 13 | parauna
# Processing Record 36 of Set 13 | necochea
# Processing Record 37 of Set 13 | tazovskiy
# Processing Record 38 of Set 13 | nsanje
# Processing Record 39 of Set 13 | havoysund
# Processing Record 40 of Set 13 | prince rupert
# Processing Record 41 of Set 13 | sibolga
# Processing Record 42 of Set 13 | aloleng
# Processing Record 43 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 13 | mumford
# Processing Record 45 of Set 13 | nizhnedevitsk
# Processing Record 46 of Set 13 | jundubah
# City not found. Skipping...
# Processing Record 47 of Set 13 | avera
# Processing Record 48 of Set 13 | montemor-o-novo
# Processing Record 49 of Set 13 | cape canaveral
# Processing Record 50 of Set 13 | paracuru
# Processing Record 1 of Set 14 | koboko
# Processing Record 2 of Set 14 | valparaiso
# Processing Record 3 of Set 14 | vostok
# Processing Record 4 of Set 14 | haimen
# Processing Record 5 of Set 14 | xiaoyi
# Processing Record 6 of Set 14 | puerto boyaca
# Processing Record 7 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 8 of Set 14 | chilca
# Processing Record 9 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 14 | mookane
# Processing Record 11 of Set 14 | bardiyah
# Processing Record 12 of Set 14 | auki
# Processing Record 13 of Set 14 | shieli
# Processing Record 14 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 14 | muravlenko
# Processing Record 16 of Set 14 | molochnoye
# Processing Record 17 of Set 14 | nuuk
# Processing Record 18 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 14 | paz de ariporo
# City not found. Skipping...
# Processing Record 20 of Set 14 | hobyo
# Processing Record 21 of Set 14 | oga
# Processing Record 22 of Set 14 | omboue
# Processing Record 23 of Set 14 | usevya
# Processing Record 24 of Set 14 | sola
# Processing Record 25 of Set 14 | the pas
# Processing Record 26 of Set 14 | xilagani
# Processing Record 27 of Set 14 | kitimat
# Processing Record 28 of Set 14 | elko
# Processing Record 29 of Set 14 | sydney
# Processing Record 30 of Set 14 | nguruka
# Processing Record 31 of Set 14 | rockhampton
# Processing Record 32 of Set 14 | bilma
# Processing Record 33 of Set 14 | suntar
# Processing Record 34 of Set 14 | alyangula
# Processing Record 35 of Set 14 | lhokseumawe
# Processing Record 36 of Set 14 | guerrero negro
# Processing Record 37 of Set 14 | madingou
# Processing Record 38 of Set 14 | imbituba
# Processing Record 39 of Set 14 | padang
# Processing Record 40 of Set 14 | ambilobe
# Processing Record 41 of Set 14 | supaul
# Processing Record 42 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 14 | finnsnes
# Processing Record 44 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 14 | sangmelima
# Processing Record 46 of Set 14 | hun
# Processing Record 47 of Set 14 | kempele
# Processing Record 48 of Set 14 | mount holly
# Processing Record 49 of Set 14 | karhal
# Processing Record 50 of Set 14 | skibbereen
# Processing Record 1 of Set 15 | itarema
# Processing Record 2 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 15 | camacha
# Processing Record 4 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 15 | talara
# Processing Record 6 of Set 15 | ciudad bolivar
# Processing Record 7 of Set 15 | la ronge
# Processing Record 8 of Set 15 | saint-louis
# Processing Record 9 of Set 15 | san luis
# Processing Record 10 of Set 15 | adwa
# Processing Record 11 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 12 of Set 15 | bulgan
# Processing Record 13 of Set 15 | chipinge
# Processing Record 14 of Set 15 | beloha
# Processing Record 15 of Set 15 | hearst
# Processing Record 16 of Set 15 | kobe
# Processing Record 17 of Set 15 | amga
# Processing Record 18 of Set 15 | panguna
# Processing Record 19 of Set 15 | isiro
# Processing Record 20 of Set 15 | sayyan
# Processing Record 21 of Set 15 | prescott valley
# Processing Record 22 of Set 15 | san felipe
# Processing Record 23 of Set 15 | klyuchi
# Processing Record 24 of Set 15 | chivay
# Processing Record 25 of Set 15 | mezen
# Processing Record 26 of Set 15 | huallanca
# Processing Record 27 of Set 15 | lodwar
# Processing Record 28 of Set 15 | nirgua
# Processing Record 29 of Set 15 | jaciara
# Processing Record 30 of Set 15 | coihaique
# Processing Record 31 of Set 15 | bestwig
# Processing Record 32 of Set 15 | vila franca do campo
# Processing Record 33 of Set 15 | ucluelet
# Processing Record 34 of Set 15 | rongcheng
# Processing Record 35 of Set 15 | mwinilunga
# Processing Record 36 of Set 15 | tirano
# Processing Record 37 of Set 15 | yar-sale
# Processing Record 38 of Set 15 | tianpeng
# Processing Record 39 of Set 15 | athabasca
# Processing Record 40 of Set 15 | manzil salim
# Processing Record 41 of Set 15 | teluknaga
# Processing Record 42 of Set 15 | kapustin yar-1
# City not found. Skipping...
# Processing Record 43 of Set 15 | henties bay
# Processing Record 44 of Set 15 | masyaf
# Processing Record 45 of Set 15 | kununurra
# Processing Record 46 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 15 | montepuez
# Processing Record 48 of Set 15 | mopti
# Processing Record 49 of Set 15 | eyl
# Processing Record 50 of Set 15 | salcininkai
# Processing Record 1 of Set 16 | ilhabela
# Processing Record 2 of Set 16 | port-cartier
# Processing Record 3 of Set 16 | serebryansk
# Processing Record 4 of Set 16 | erenhot
# Processing Record 5 of Set 16 | kerman
# Processing Record 6 of Set 16 | benito juarez
# Processing Record 7 of Set 16 | nanchong
# Processing Record 8 of Set 16 | raga
# Processing Record 9 of Set 16 | kumbo
# Processing Record 10 of Set 16 | borogontsy
# Processing Record 11 of Set 16 | hualmay
# Processing Record 12 of Set 16 | belaya gora
# Processing Record 13 of Set 16 | ordu
# Processing Record 14 of Set 16 | masvingo
# Processing Record 15 of Set 16 | laurel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kirtipur      NP  27.67   85.28     73.40        94          40
# 1       Qaanaaq      GL  77.48  -69.36     33.22        78           0
# 2        Bethel      US  41.37  -73.41     71.01        60          75
# 3       Huilong      CN  31.81  121.66     86.00        92           0
# 4     Busselton      AU -33.65  115.33     45.00        67           0
# 5  Saint Helens      GB  53.45   -2.73     63.00        51          40
# 6        Xining      CN  36.62  101.77     48.18        81           4
# 7     Grindavik      IS  63.84  -22.43     53.60       100          90
# 8       Bubaque      GW  11.28  -15.83     80.80        80          85
# 9      Atherton      GB  53.52   -2.49     63.00        45          97
#
#    Wind Speed   Current Weather                 Date
# 0        5.82  scattered clouds  2020-08-30 15:39:58
# 1        6.08         clear sky  2020-08-30 15:39:58
# 2       10.29     broken clouds  2020-08-30 15:39:27
# 3        3.00        light rain  2020-08-30 15:39:58
# 4        4.74         clear sky  2020-08-30 15:39:59
# 5        6.93  scattered clouds  2020-08-30 15:39:59
# 6        0.51         clear sky  2020-08-30 15:39:59
# 7       27.51   overcast clouds  2020-08-30 15:40:00
# 8       14.47   overcast clouds  2020-08-30 15:35:43
# 9        1.99   overcast clouds  2020-08-30 15:35:37

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
